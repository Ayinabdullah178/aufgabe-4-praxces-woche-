# %% [markdown]
# tagsaufgabe4

# %%
from folium.plugins import MarkerCluster
import geocoder
import geopy
import geographiclib 
import folium

# %%
from folium.plugins import MarkerCluster
import geocoder
import geopy
import geographiclib 
import folium
l1=[51.86302651225799, 14.303517607750853]
l2=[51.85072785983121, 14.333730009985139]
l3=[51.85369680785648, 14.391408232432404]
l4=[51.82145203311944, 14.386601713895132]
l5=[51.801924239925434, 14.426427153203957]
l6=[51.7998011438578, 14.475178984082005]
l7=[51.779839153678644, 14.49989822227369]
l8=[51.75094233690071, 14.458699491954212]
l9=[51.75306773290255, 14.391408232432404]
l10=[51.70330725026829, 14.443593290837073]
l11=[51.7126681039688, 14.380421904347212]
l12=[51.70075395397841, 14.304890898761505]
l13=[51.73946347012492, 14.275365142032546]
l14=[51.77219179637781, 14.282918242591116]
l15=[51.785786202292854, 14.281544951580466]
l16=[51.806170132135506, 14.289098052139035]
l17=[51.80447182323888, 14.271931914505922]
l18=[51.83248573888619, 14.303517607750853]
l19=[51.86302651225799, 14.303517607750853]
Cottbus =[l1,l2,l3,l4,l5,l6,l7,l8,l9,l10,l11,l12,l13,l14,l15,l16,l17,l18,l19]
m = folium.Map(
    location=[51.77644018003645, 14.331678497474792],
    tiles="cartodbpositron",
    zoom_start=10,
)

tooltip = "start_end"

folium.Circle(
    l1, radius=1, popup="start", tooltip=tooltip
).add_to(m)
folium.Circle(
    l19, radius=1, popup="ende", tooltip=tooltip
).add_to(m)

folium.PolyLine(Cottbus, color="green", weight=3, opacity=0.5).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
#supermarket Koordinaten
rewe1=[51.759874538503375, 14.321697126438531]
rewe2=[51.76101370951663, 14.317491997670924]
rewe3=[51.76356264386852, 14.348207511162974]
rewe4=[51.75862823402112, 14.347392155342817]
rewe5=[51.744178938934034, 14.312173382326092]
aldi1=[51.76229774922117, 14.30775015630253]
aldi2=[51.732410079939605, 14.334081234411753]
aldi3=[51.779134813310066, 14.324865357073527]
aldi4=[51.76854448969701, 14.354707245597313]
netto1=[51.72269545244656, 14.350895213518905]
netto2=[51.73417376949376, 14.328657217838034]
netto3=[51.74761609127726, 14.33183407436387]
netto4=[51.749346049960046, 14.335495169027789]
netto5=[51.74841280253195, 14.312582638163873]
netto6=[51.76296926671386, 14.337907014381885]
netto7=[51.78087847418009, 14.327958152296237]
netto8=[51.76091671621119, 14.308361908794206]
lidl1=[51.72078593987464, 14.318017487051469]
lidl2=[51.74502569826217, 14.323510651094066]
lidl4=[51.761178315326354, 14.312867645761536]
lidl5=[51.76202829304375, 14.348229889285754]
lidl6=[51.767552758175924, 14.358529571865622]
lidl7=[51.78900676691, 14.350289825801726]
lidl8=[51.787520184390566, 14.350289825801726]
edeka1=[51.72095697430019, 14.31183753022678]
edeka2=[51.777920813535566, 14.345139837235024]
marketkauf=[51.722658427695464, 14.321450567301325]
penny1=[51.728784015091136, 14.322137065530423]
penny2=[51.71091798160905, 14.350632854001393]
#Koordinaten für Stadt grenze
l1=[51.86302651225799, 14.303517607750853]
l2=[51.85072785983121, 14.333730009985139]
l3=[51.85369680785648, 14.391408232432404]
l4=[51.82145203311944, 14.386601713895132]
l5=[51.801924239925434, 14.426427153203957]
l6=[51.7998011438578, 14.475178984082005]
l7=[51.779839153678644, 14.49989822227369]
l8=[51.75094233690071, 14.458699491954212]
l9=[51.75306773290255, 14.391408232432404]
l10=[51.70330725026829, 14.443593290837073]
l11=[51.7126681039688, 14.380421904347212]
l12=[51.70075395397841, 14.304890898761505]
l13=[51.73946347012492, 14.275365142032546]
l14=[51.77219179637781, 14.282918242591116]
l15=[51.785786202292854, 14.281544951580466]
l16=[51.806170132135506, 14.289098052139035]
l17=[51.80447182323888, 14.271931914505922]
l18=[51.83248573888619, 14.303517607750853]
l19=[51.86302651225799, 14.303517607750853]
Cottbus =[l1,l2,l3,l4,l5,l6,l7,l8,l9,l10,l11,l12,l13,l14,l15,l16,l17,l18,l19]

#Marke empfehlen
empfelung1=[51.76990334950071, 14.371110294157852]
empfelung2=[51.755142489930904, 14.324584621313512]
empfelung3=[51.7690209921035, 14.318716356743924]
empfelung4=[51.769622593318196, 14.335891193212321]





m = folium.Map(location=[51.77644018003645, 14.331678497474792],tiles="cartodbpositron", zoom_start=10)

tooltip = "Informationen:"



folium.Marker(
    rewe1, popup="rewe1", tooltip=tooltip,icon=folium.Icon(color="red")).add_to(m)

folium.Marker(
    rewe2, popup="rewe2", tooltip=tooltip,icon=folium.Icon(color="red")).add_to(m)
folium.Marker(
    rewe3, popup="rewe3", tooltip=tooltip,icon=folium.Icon(color="red")).add_to(m)
folium.Marker(
    rewe4, popup="rewe4", tooltip=tooltip,icon=folium.Icon(color="red")).add_to(m)
folium.Marker(
    rewe5, popup="rewe5", tooltip=tooltip,icon=folium.Icon(color="red")).add_to(m)
folium.Marker(
    aldi1, popup="aldi1", tooltip=tooltip, icon=folium.Icon(color="blue", icon_color="white")).add_to(m)
folium.Marker(
    aldi2, popup="aldi2", tooltip=tooltip, icon=folium.Icon(color="blue", icon_color="white")).add_to(m)
folium.Marker(
    aldi3, popup="aldi3", tooltip=tooltip, icon=folium.Icon(color="blue", icon_color="white")).add_to(m)
folium.Marker(
    aldi4, popup="aldi4", tooltip=tooltip, icon=folium.Icon(color="blue", icon_color="white")).add_to(m)
folium.Marker(
    netto1, popup="netto1", tooltip=tooltip, icon=folium.Icon(color="orange")).add_to(m)
folium.Marker(
    netto2, popup="netto2", tooltip=tooltip, icon=folium.Icon(color="orange")).add_to(m)
folium.Marker(
    netto3, popup="netto3", tooltip=tooltip, icon=folium.Icon(color="orange")).add_to(m)
folium.Marker(
    netto4, popup="netto4", tooltip=tooltip, icon=folium.Icon(color="orange")).add_to(m)
folium.Marker(
    netto5, popup="netto5", tooltip=tooltip, icon=folium.Icon(color="orange")).add_to(m)
folium.Marker(
    netto6, popup="netto6", tooltip=tooltip, icon=folium.Icon(color="orange")).add_to(m)
folium.Marker(
    netto7, popup="netto7", tooltip=tooltip, icon=folium.Icon(color="orange")).add_to(m)
folium.Marker(
    netto8, popup="netto8", tooltip=tooltip, icon=folium.Icon(color="orange")).add_to(m)
folium.Marker(
    lidl1, popup="lidl1", tooltip=tooltip, icon=folium.Icon(color="pink")).add_to(m)
folium.Marker(
    lidl2, popup="lidl2", tooltip=tooltip, icon=folium.Icon(color="pink")).add_to(m)
folium.Marker(
    lidl4, popup="lidl4", tooltip=tooltip, icon=folium.Icon(color="pink")).add_to(m)
folium.Marker(
    lidl5, popup="lidl5", tooltip=tooltip, icon=folium.Icon(color="pink")).add_to(m)
folium.Marker(
    lidl6, popup="lidl6", tooltip=tooltip, icon=folium.Icon(color="pink")).add_to(m)
folium.Marker(
    lidl7, popup="lidl7", tooltip=tooltip, icon=folium.Icon(color="pink")).add_to(m)
folium.Marker(
    lidl8, popup="lidl8", tooltip=tooltip, icon=folium.Icon(color="pink")).add_to(m)
folium.Marker(
    edeka1, popup="edeka1", tooltip=tooltip, icon=folium.Icon(color="green")).add_to(m)
folium.Marker(
    edeka2, popup="edeka2", tooltip=tooltip, icon=folium.Icon(color="green")).add_to(m)
folium.Marker(
    penny1, popup="penny1", tooltip=tooltip, icon=folium.Icon(color="lightblue")).add_to(m)
folium.Marker(
    penny2, popup="penny2", tooltip=tooltip, icon=folium.Icon(color="lightblue")).add_to(m)
folium.Marker(
    marketkauf, popup="marketkauf", tooltip=tooltip, icon=folium.Icon(color="purpel")).add_to(m)



folium.Circle(
    location=empfelung1,radius=500,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(m)

folium.Circle(
    location=empfelung2,radius=500,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(m)

folium.Circle(
    location=empfelung3,radius=500,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(m)

folium.Circle(
    location=empfelung4,radius=500,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(m)

folium.Circle(
    l1, radius=1, popup="start", tooltip=tooltip
).add_to(m)
folium.Circle(
    l19, radius=1, popup="ende", tooltip=tooltip
).add_to(m)

folium.PolyLine(Cottbus, color="green", weight=3, opacity=0.5).add_to(m)
m
# Out:
# C:\Users\49163\AppData\Local\Temp\ipykernel_27744\1918368789.py:128: UserWarning: color argument of Icon should be one of: {'lightgray', 'white', 'darkblue', 'lightred', 'orange', 'darkpurple', 'cadetblue', 'darkred', 'beige', 'purple', 'black', 'green', 'gray', 'pink', 'blue', 'red', 'lightblue', 'lightgreen', 'darkgreen'}.
#   marketkauf, popup="marketkauf", tooltip=tooltip, icon=folium.Icon(color="purpel")).add_to(m)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
# ...

# %%
import folium
#supermarket Koordinaten
rewe1=[51.759874538503375, 14.321697126438531]
rewe2=[51.76101370951663, 14.317491997670924]
rewe3=[51.76356264386852, 14.348207511162974]
rewe4=[51.75862823402112, 14.347392155342817]
rewe5=[51.744178938934034, 14.312173382326092]
aldi1=[51.76229774922117, 14.30775015630253]
aldi2=[51.732410079939605, 14.334081234411753]
aldi3=[51.779134813310066, 14.324865357073527]
aldi4=[51.76854448969701, 14.354707245597313]
netto1=[51.72269545244656, 14.350895213518905]
netto2=[51.73417376949376, 14.328657217838034]
netto3=[51.74761609127726, 14.33183407436387]
netto4=[51.749346049960046, 14.335495169027789]
netto5=[51.74841280253195, 14.312582638163873]
netto6=[51.76296926671386, 14.337907014381885]
netto7=[51.78087847418009, 14.327958152296237]
netto8=[51.76091671621119, 14.308361908794206]
lidl1=[51.72078593987464, 14.318017487051469]
lidl2=[51.74502569826217, 14.323510651094066]
lidl4=[51.761178315326354, 14.312867645761536]
lidl5=[51.76202829304375, 14.348229889285754]
lidl6=[51.767552758175924, 14.358529571865622]
lidl7=[51.78900676691, 14.350289825801726]
lidl8=[51.787520184390566, 14.350289825801726]
edeka1=[51.72095697430019, 14.31183753022678]
edeka2=[51.777920813535566, 14.345139837235024]
marketkauf=[51.722658427695464, 14.321450567301325]
penny1=[51.728784015091136, 14.322137065530423]
penny2=[51.71091798160905, 14.350632854001393]
#Koordinaten für Stadt grenze
l1=[51.86302651225799, 14.303517607750853]
l2=[51.85072785983121, 14.333730009985139]
l3=[51.85369680785648, 14.391408232432404]
l4=[51.82145203311944, 14.386601713895132]
l5=[51.801924239925434, 14.426427153203957]
l6=[51.7998011438578, 14.475178984082005]
l7=[51.779839153678644, 14.49989822227369]
l8=[51.75094233690071, 14.458699491954212]
l9=[51.75306773290255, 14.391408232432404]
l10=[51.70330725026829, 14.443593290837073]
l11=[51.7126681039688, 14.380421904347212]
l12=[51.70075395397841, 14.304890898761505]
l13=[51.73946347012492, 14.275365142032546]
l14=[51.77219179637781, 14.282918242591116]
l15=[51.785786202292854, 14.281544951580466]
l16=[51.806170132135506, 14.289098052139035]
l17=[51.80447182323888, 14.271931914505922]
l18=[51.83248573888619, 14.303517607750853]
l19=[51.86302651225799, 14.303517607750853]
Cottbus =[l1,l2,l3,l4,l5,l6,l7,l8,l9,l10,l11,l12,l13,l14,l15,l16,l17,l18,l19]

#Marke empfehlen
empfelung1=[51.76990334950071, 14.371110294157852]
empfelung2=[51.755142489930904, 14.324584621313512]
empfelung3=[51.7690209921035, 14.318716356743924]
empfelung4=[51.769622593318196, 14.335891193212321]


v = folium.Map(location=[51.77644018003645, 14.331678497474792],tiles="cartodbpositron", zoom_start=10)

tooltip = "Informationen:"

folium.Circle(
    location=rewe1,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=rewe2,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=rewe3,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=rewe4,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=rewe5,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=aldi1,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=aldi2,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=aldi3,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=aldi4,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=netto1,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=netto2,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=netto3,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=netto4,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=netto5,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=netto6,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=netto7,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=netto8,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=lidl1,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=lidl2,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=lidl4,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=lidl5,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=lidl6,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=lidl7,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=lidl8,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=edeka1,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=edeka2,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=penny1,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=penny2,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)
folium.Circle(
    location=marketkauf,radius=400,popup="Sportplatz",color="#3186cc",fill=True,fill_color="crimson",).add_to(v)




folium.Circle(
    location=empfelung1,radius=400,popup="empfelung1",color="green",fill=True,fill_color="crimson",).add_to(v)

folium.Circle(
    location=empfelung2,radius=400,popup="empfelung2",color="green",fill=True,fill_color="crimson",).add_to(v)

folium.Circle(
    location=empfelung3,radius=400,popup="empfelung3",color="green",fill=True,fill_color="crimson",).add_to(v)

folium.Circle(
    location=empfelung4,radius=400,popup="empfelung4",color="green",fill=True,fill_color="crimson",).add_to(v)



folium.Circle(
    l1, radius=1, popup="start", tooltip=tooltip).add_to(v)
folium.Circle(
    l19, radius=1, popup="ende", tooltip=tooltip).add_to(v)

folium.PolyLine(Cottbus, color="green", weight=3, opacity=0.5).add_to(v)
v
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
